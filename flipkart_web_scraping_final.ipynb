# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# Function to extract Product Title
def get_title(soup):

    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"class":"VU-ZEz"})
        
        # Inner NavigatableString Object
        title_value = title.text

        # Title as a string value
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(soup):

    try:
        price = soup.find("span", attrs={"class":"Nx9bqj CxhGGd"}).string.strip()

    except AttributeError:

        try:
            # If there is some deal price
            price = soup.find("div", attrs={"class":"Nx9bqj CxhGGd"}).string.strip()

        except:
            price = ""

    return price

# Function to extract Product Rating
def get_rating(soup):

    try:
        rating = soup.find("div", attrs={"class":"XQDdHH"}).text.strip()
    
    except AttributeError:
        try:
            rating = soup.find("span", attrs={"class":"XQDdHH"}).text.strip()
        except:
            rating = ""	

    return rating

# Function to extract Number of User Reviews
#def get_review_count(soup):
    #try:
        #review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()

    #except AttributeError:
        #review_count = ""	

    #return review_count

# Function to extract Availability Status
#def get_availability(soup):
    #try:
        #available = soup.find("div", attrs={'id':'availability'})
        #available = available.find("span").string.strip()

    #except AttributeError:
        #available = "Not Available"	

    #return available

# %%
if __name__ == '__main__':

    # add your user agent 
    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36', 'Accept-Language': 'en-US, en;q=0.5'})

    # The webpage URL
    URL = "https://www.flipkart.com/search?q=playstation+5&sid=4rr%2Cx1m&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&as-pos=1&as-type=RECENT&suggestionId=playstation+5%7CGaming+Consoles&requestId=5ae8bbd6-7df3-4da9-9103-6506babbd145&as-backfill=on"

    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)

    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'wjcEIp'})

    # Store the links
    links_list = []

    # Loop for extracting links from Tag Objects
    for link in links:
            links_list.append(link.get('href'))

    d = {"title":[], "price":[], "rating":[]}
    
    # Loop for extracting product details from each link 
    for link in links_list:
        new_webpage = requests.get("https://www.flipkart.com" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d['title'].append(get_title(new_soup))
        d['price'].append(get_price(new_soup))
        d['rating'].append(get_rating(new_soup))
        #d['reviews'].append(get_review_count(new_soup))
        #d['availability'].append(get_availability(new_soup))

    
    flipkart_df = pd.DataFrame.from_dict(d)
    flipkart_df['title'].replace('', np.nan, inplace=True)
    flipkart_df = flipkart_df.dropna(subset=['title'])
    flipkart_df.to_csv("flipkart_data.csv", header=True, index=False)

# %%
flipkart_df
# Out:
#                                                 title    price rating
# 0   SONY PlayStation 5 console- Cricket 24 825 GB ...  ₹57,990    4.7
# 1   SONY PlayStation 5 Digital Edition 825 GB with...  ₹44,990    4.8
# 2   SONY PlayStation5 Console (slim) CFI-2008A01X ...  ₹49,990    4.7
# 3   SONY PlayStation5 Digital Edition (slim) CFI-2...  ₹39,990    4.7
# 4             SONY PlayStation 5 console 825 GB  (NA)  ₹54,990    4.7
# 5   SONY Brand New Latest PlayStation Portal Remot...  ₹26,999      5
# 6   Gameson PSP Built-in Games MP4 Player Ebook Tv...   ₹3,399    3.5
# 7   TECHZONE X7 PSP Portable Video Games Classic G...   ₹3,399    2.3
# 8   TECHZONE X7 PSP Portable Video Games Classic G...   ₹3,399    3.5
# 9   TECHZONE X7 Plus 5.1 PSP 8G psp Console 2000 G...   ₹3,249    3.5
# 10  Hgworld Sup R35X Retro 400+ Classic Video Game...     ₹499      4
# 11  BSVR Newly 400 Games Super Mario 057 Gaming Co...     ₹573    3.7
# 12  Valve Steam Deck Latest Oled Edition 512 GB  (...  ₹58,990    4.9
# 13  SONY Playstation 4 Brand New Ps4 Slim Console ...  ₹30,412    4.9
# 14  NextTech G5 500 In1 Handheld Colorful Mini Gam...     ₹989      5
# 15  SONY Playstation Brand New Ps4 Slim Console 1T...  ₹31,987    4.7
# 16  Gameson X7 PSP HDMI Games MP4 Player Tv Out Po...   ₹3,449      4
# 17  TECHZONE X7 Plus 5.1 PSP 8G psp Console 2000 G...   ₹3,399    3.7
# 18  Clubics PVP Gaming Console - Pocket Game (RED)...     ₹835    3.7
# 19  POWERNRI PVP Station Light 3000 Game .160 GB w...     ₹839    3.7
# 20  Clubics Best PVP Ga\nng Console for Kids-PVP(B...     ₹835    3.5
# 21  Grabit POCKET MP4 PLAYER WITH 10000 GAMES INCL...   ₹2,456      3
# 22  Grabit I_NE-XT IN-1001 4 GB with VINTAGE CAR R...   ₹2,549    3.8
# 23  Grabit POCKETMP4 PLAYER WITH 10000 GAMES INCLU...   ₹2,558    3.4
# 24  Clubics X20 5.1 inch HD Screen 8GB Memory/MP3 ...   ₹4,249    3.6
# 25                 SONY Ps4 Slim Console 1TB  (Black)  ₹31,987    3.9
# 26  PSS Charging Station for PS5 DualSense Control...   ₹2,899    3.7
# 27  TECHZONE PSP Built-in Games MP4 Player Tv Out ...   ₹2,734    3.4
# 28  markif 8 BIT GS5 TV GAME CONSOLE INBUILT 200 C...   ₹1,449    3.2
# 29              SONY Ps4 Slim Console 500 GB  (Black)  ₹30,412    3.9
# 30  Novax Divaa Store 101000 in 1 Video game 1 GB ...     ₹899    3.1
# 31  SONY Playstation 4 Brand New Ps4 Slim Console ...  ₹36,350    4.1
# 32  TECHZONE X7 PSP Game Console Support TV Output...   ₹3,389      3
# 33  GLOWISH TFT SCREEN DOUBLE ROCKER POCKET GAME P...   ₹2,999    3.8
# 34  TECHZONE PSP Built-in Games MP4 Player Tv Out ...   ₹2,739    3.3
# 35  Clubics X20 Gaming Box ARCADE PUZZLE Game inbu...   ₹4,249    3.4
# 36  PTCMart Dual System in 1 Box, 5000+Games inbui...   ₹3,999    3.4
# 37  NextTech Colorful G5s 500 In1 Handheld Mini Ga...     ₹989    3.3
# 38  TECHZONE X7 Handheld Game Console psp with Pre...   ₹3,399    3.5
# 39  NextTech X7 PSP Game Console:Unlock The Power ...   ₹4,999    3.3
